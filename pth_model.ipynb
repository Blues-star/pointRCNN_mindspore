# %%
import torch

d = torch.load("pretrain_pth/PointRCNN.pth")
print(type(d))
# Out:
# <class 'dict'>

# %%
for item in d["model_state"].keys():
    print(item)
# Out:
# rpn.backbone_net.SA_modules.0.mlps.0.layer0.conv.weight
# rpn.backbone_net.SA_modules.0.mlps.0.layer0.bn.bn.weight
# rpn.backbone_net.SA_modules.0.mlps.0.layer0.bn.bn.bias
# rpn.backbone_net.SA_modules.0.mlps.0.layer0.bn.bn.running_mean
# rpn.backbone_net.SA_modules.0.mlps.0.layer0.bn.bn.running_var
# rpn.backbone_net.SA_modules.0.mlps.0.layer0.bn.bn.num_batches_tracked
# rpn.backbone_net.SA_modules.0.mlps.0.layer1.conv.weight
# rpn.backbone_net.SA_modules.0.mlps.0.layer1.bn.bn.weight
# rpn.backbone_net.SA_modules.0.mlps.0.layer1.bn.bn.bias
# rpn.backbone_net.SA_modules.0.mlps.0.layer1.bn.bn.running_mean
# rpn.backbone_net.SA_modules.0.mlps.0.layer1.bn.bn.running_var
# rpn.backbone_net.SA_modules.0.mlps.0.layer1.bn.bn.num_batches_tracked
# rpn.backbone_net.SA_modules.0.mlps.0.layer2.conv.weight
# rpn.backbone_net.SA_modules.0.mlps.0.layer2.bn.bn.weight
# rpn.backbone_net.SA_modules.0.mlps.0.layer2.bn.bn.bias
# rpn.backbone_net.SA_modules.0.mlps.0.layer2.bn.bn.running_mean
# ...
